# %% [markdown]
# <a href="https://colab.research.google.com/github/joaopamaral/aind2-cnn/blob/master/transfer-learning/transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we use transfer learning to train a CNN to classify dog breeds.
#
# ### 1. Load Dog Dataset
#
# Before running the code cell below, download the dataset of dog images [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip) and place it in the respository.

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # !wget -nc https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
    # !unzip -nq dogImages.zip
    # !mkdir -p
# Out:
# File ‘dogImages.zip’ already there; not retrieving.

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load ordered list of dog names
dog_names = [item[25:-1] for item in glob('dogImages/train/*/')]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % str(len(train_files) + len(valid_files) + len(test_files)))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 2. Visualize the First 12 Training Images

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def visualize_img(img_path, ax):
    img = cv2.imread(img_path)
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    
fig = plt.figure(figsize=(20, 10))
for i in range(12):
    ax = fig.add_subplot(3, 4, i + 1, xticks=[], yticks=[])
    visualize_img(train_files[i], ax)

# %% [markdown]
# ### 3. Obtain the VGG-16 Bottleneck Features
#
# Before running the code cell below, download the file linked [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG16Data.npz) and place it in the `bottleneck_features/` folder.

# %%
if IN_COLAB:
    # !wget -nc -q https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG16Data.npz

# %%
bottleneck_features = np.load('DogVGG16Data.npz')
train_vgg16 = bottleneck_features['train']
valid_vgg16 = bottleneck_features['valid']
test_vgg16 = bottleneck_features['test']

# %% [markdown]
# ### 4. Define a Model Architecture (Model 1)

# %%
from keras.layers import Dense, Flatten
from keras.models import Sequential

model = Sequential()
model.add(Flatten(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               3336837
# =================================================================
# Total params: 3,336,837
# Trainable params: 3,336,837
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5. Define another Model Architecture (Model 2)

# %%
from keras.layers import GlobalAveragePooling2D

model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model (Model 2)

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model (Model 2)

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='dogvgg16.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit(train_vgg16, train_targets, epochs=100, validation_data=(valid_vgg16, valid_targets), 
          callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 5.6871 - acc: 0.6442 - val_loss: 6.5026 - val_acc: 0.5246
#
# Epoch 00001: val_loss improved from inf to 6.50261, saving model to dogvgg16.weights.best.hdf5
# Epoch 2/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 5.6694 - acc: 0.6415 - val_loss: 6.5861 - val_acc: 0.5222
#
# Epoch 00002: val_loss did not improve from 6.50261
# Epoch 3/100
# 6680/6680 [==============================] - 1s 141us/step - loss: 5.5357 - acc: 0.6418 - val_loss: 6.3993 - val_acc: 0.5150
#
# Epoch 00003: val_loss improved from 6.50261 to 6.39929, saving model to dogvgg16.weights.best.hdf5
# Epoch 4/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 5.3215 - acc: 0.6533 - val_loss: 6.1607 - val_acc: 0.5222
#
# Epoch 00004: val_loss improved from 6.39929 to 6.16071, saving model to dogvgg16.weights.best.hdf5
# Epoch 5/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 5.1563 - acc: 0.6653 - val_loss: 6.1340 - val_acc: 0.5353
#
# Epoch 00005: val_loss improved from 6.16071 to 6.13398, saving model to dogvgg16.weights.best.hdf5
# Epoch 6/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 4.9609 - acc: 0.6751 - val_loss: 6.1533 - val_acc: 0.5341
#
# Epoch 00006: val_loss did not improve from 6.13398
# Epoch 7/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 4.8858 - acc: 0.6853 - val_loss: 5.8955 - val_acc: 0.5509
#
# Epoch 00007: val_loss improved from 6.13398 to 5.89555, saving model to dogvgg16.weights.best.hdf5
# Epoch 8/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 4.8576 - acc: 0.6915 - val_loss: 5.9338 - val_acc: 0.5485
#
# Epoch 00008: val_loss did not improve from 5.89555
# Epoch 9/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 4.8403 - acc: 0.6955 - val_loss: 5.9285 - val_acc: 0.5569
#
# Epoch 00009: val_loss did not improve from 5.89555
# Epoch 10/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 4.8284 - acc: 0.6981 - val_loss: 5.8600 - val_acc: 0.5545
#
# Epoch 00010: val_loss improved from 5.89555 to 5.86000, saving model to dogvgg16.weights.best.hdf5
# Epoch 11/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 4.7392 - acc: 0.6958 - val_loss: 5.8685 - val_acc: 0.5401
#
# Epoch 00011: val_loss did not improve from 5.86000
# Epoch 12/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 4.6027 - acc: 0.7042 - val_loss: 5.8656 - val_acc: 0.5533
#
# Epoch 00012: val_loss did not improve from 5.86000
# Epoch 13/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 4.4993 - acc: 0.7064 - val_loss: 5.6423 - val_acc: 0.5593
#
# Epoch 00013: val_loss improved from 5.86000 to 5.64233, saving model to dogvgg16.weights.best.hdf5
# Epoch 14/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 4.3823 - acc: 0.7157 - val_loss: 5.6597 - val_acc: 0.5497
#
# Epoch 00014: val_loss did not improve from 5.64233
# Epoch 15/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 4.3199 - acc: 0.7198 - val_loss: 5.6232 - val_acc: 0.5605
#
# Epoch 00015: val_loss improved from 5.64233 to 5.62323, saving model to dogvgg16.weights.best.hdf5
# Epoch 16/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 4.2007 - acc: 0.7271 - val_loss: 5.5733 - val_acc: 0.5545
#
# Epoch 00016: val_loss improved from 5.62323 to 5.57330, saving model to dogvgg16.weights.best.hdf5
# Epoch 17/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 4.1711 - acc: 0.7329 - val_loss: 5.5772 - val_acc: 0.5473
#
# Epoch 00017: val_loss did not improve from 5.57330
# Epoch 18/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 4.1525 - acc: 0.7362 - val_loss: 5.4700 - val_acc: 0.5808
#
# Epoch 00018: val_loss improved from 5.57330 to 5.47002, saving model to dogvgg16.weights.best.hdf5
# Epoch 19/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 4.1439 - acc: 0.7389 - val_loss: 5.4822 - val_acc: 0.5677
#
# Epoch 00019: val_loss did not improve from 5.47002
# Epoch 20/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 4.1282 - acc: 0.7388 - val_loss: 5.5612 - val_acc: 0.5557
#
# Epoch 00020: val_loss did not improve from 5.47002
# Epoch 21/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 4.0449 - acc: 0.7427 - val_loss: 5.3489 - val_acc: 0.5701
#
# Epoch 00021: val_loss improved from 5.47002 to 5.34886, saving model to dogvgg16.weights.best.hdf5
# Epoch 22/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 4.0233 - acc: 0.7476 - val_loss: 5.2956 - val_acc: 0.5796
#
# Epoch 00022: val_loss improved from 5.34886 to 5.29556, saving model to dogvgg16.weights.best.hdf5
# Epoch 23/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 4.0214 - acc: 0.7481 - val_loss: 5.3731 - val_acc: 0.5725
#
# Epoch 00023: val_loss did not improve from 5.29556
# Epoch 24/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 4.0158 - acc: 0.7491 - val_loss: 5.3911 - val_acc: 0.5760
#
# Epoch 00024: val_loss did not improve from 5.29556
# Epoch 25/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.9891 - acc: 0.7481 - val_loss: 5.3726 - val_acc: 0.5737
#
# Epoch 00025: val_loss did not improve from 5.29556
# Epoch 26/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 3.9480 - acc: 0.7509 - val_loss: 5.3225 - val_acc: 0.5772
#
# Epoch 00026: val_loss did not improve from 5.29556
# Epoch 27/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 3.9373 - acc: 0.7519 - val_loss: 5.3562 - val_acc: 0.5737
#
# Epoch 00027: val_loss did not improve from 5.29556
# Epoch 28/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 3.8589 - acc: 0.7493 - val_loss: 5.2934 - val_acc: 0.5701
#
# Epoch 00028: val_loss improved from 5.29556 to 5.29344, saving model to dogvgg16.weights.best.hdf5
# Epoch 29/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.6307 - acc: 0.7605 - val_loss: 5.1705 - val_acc: 0.5749
#
# Epoch 00029: val_loss improved from 5.29344 to 5.17046, saving model to dogvgg16.weights.best.hdf5
# Epoch 30/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.5541 - acc: 0.7690 - val_loss: 5.0469 - val_acc: 0.6036
#
# Epoch 00030: val_loss improved from 5.17046 to 5.04685, saving model to dogvgg16.weights.best.hdf5
# Epoch 31/100
# 6680/6680 [==============================] - 1s 143us/step - loss: 3.5215 - acc: 0.7754 - val_loss: 4.9596 - val_acc: 0.6036
#
# Epoch 00031: val_loss improved from 5.04685 to 4.95960, saving model to dogvgg16.weights.best.hdf5
# Epoch 32/100
# 6680/6680 [==============================] - 1s 144us/step - loss: 3.5107 - acc: 0.7778 - val_loss: 4.9997 - val_acc: 0.6012
#
# Epoch 00032: val_loss did not improve from 4.95960
# Epoch 33/100
# 6680/6680 [==============================] - 1s 141us/step - loss: 3.5027 - acc: 0.7795 - val_loss: 4.9973 - val_acc: 0.5988
#
# Epoch 00033: val_loss did not improve from 4.95960
# Epoch 34/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.4732 - acc: 0.7790 - val_loss: 4.9604 - val_acc: 0.5892
#
# Epoch 00034: val_loss did not improve from 4.95960
# Epoch 35/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 3.3649 - acc: 0.7828 - val_loss: 4.9196 - val_acc: 0.5868
#
# Epoch 00035: val_loss improved from 4.95960 to 4.91961, saving model to dogvgg16.weights.best.hdf5
# Epoch 36/100
# 6680/6680 [==============================] - 1s 145us/step - loss: 3.3079 - acc: 0.7882 - val_loss: 4.8883 - val_acc: 0.6000
#
# Epoch 00036: val_loss improved from 4.91961 to 4.88828, saving model to dogvgg16.weights.best.hdf5
# Epoch 37/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 3.2886 - acc: 0.7927 - val_loss: 4.9248 - val_acc: 0.5940
#
# Epoch 00037: val_loss did not improve from 4.88828
# Epoch 38/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.2629 - acc: 0.7916 - val_loss: 4.9133 - val_acc: 0.6012
#
# Epoch 00038: val_loss did not improve from 4.88828
# Epoch 39/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 3.2197 - acc: 0.7951 - val_loss: 4.8852 - val_acc: 0.5880
#
# Epoch 00039: val_loss improved from 4.88828 to 4.88524, saving model to dogvgg16.weights.best.hdf5
# Epoch 40/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.1581 - acc: 0.7961 - val_loss: 4.7759 - val_acc: 0.6072
#
# Epoch 00040: val_loss improved from 4.88524 to 4.77585, saving model to dogvgg16.weights.best.hdf5
# Epoch 41/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 3.0650 - acc: 0.8043 - val_loss: 4.7203 - val_acc: 0.6012
#
# Epoch 00041: val_loss improved from 4.77585 to 4.72031, saving model to dogvgg16.weights.best.hdf5
# Epoch 42/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 3.0517 - acc: 0.8070 - val_loss: 4.8829 - val_acc: 0.6108
#
# Epoch 00042: val_loss did not improve from 4.72031
# Epoch 43/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.0434 - acc: 0.8084 - val_loss: 4.8548 - val_acc: 0.5928
#
# Epoch 00043: val_loss did not improve from 4.72031
# Epoch 44/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.0338 - acc: 0.8097 - val_loss: 4.8265 - val_acc: 0.6096
#
# Epoch 00044: val_loss did not improve from 4.72031
# Epoch 45/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 3.0264 - acc: 0.8102 - val_loss: 4.7142 - val_acc: 0.6084
#
# Epoch 00045: val_loss improved from 4.72031 to 4.71418, saving model to dogvgg16.weights.best.hdf5
# Epoch 46/100
# 6680/6680 [==============================] - 1s 140us/step - loss: 3.0206 - acc: 0.8111 - val_loss: 4.8195 - val_acc: 0.6024
#
# Epoch 00046: val_loss did not improve from 4.71418
# Epoch 47/100
# 6680/6680 [==============================] - 1s 142us/step - loss: 3.0222 - acc: 0.8109 - val_loss: 4.8115 - val_acc: 0.6144
#
# Epoch 00047: val_loss did not improve from 4.71418
# Epoch 48/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 3.0165 - acc: 0.8123 - val_loss: 4.7562 - val_acc: 0.6120
#
# Epoch 00048: val_loss did not improve from 4.71418
# Epoch 49/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 3.0148 - acc: 0.8121 - val_loss: 4.7296 - val_acc: 0.6156
#
# Epoch 00049: val_loss did not improve from 4.71418
# Epoch 50/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 3.0110 - acc: 0.8120 - val_loss: 4.6793 - val_acc: 0.6108
#
# Epoch 00050: val_loss improved from 4.71418 to 4.67934, saving model to dogvgg16.weights.best.hdf5
# Epoch 51/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9973 - acc: 0.8115 - val_loss: 4.9329 - val_acc: 0.6096
#
# Epoch 00051: val_loss did not improve from 4.67934
# Epoch 52/100
# 6680/6680 [==============================] - 1s 137us/step - loss: 2.9740 - acc: 0.8124 - val_loss: 4.7003 - val_acc: 0.6228
#
# Epoch 00052: val_loss did not improve from 4.67934
# Epoch 53/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9541 - acc: 0.8145 - val_loss: 4.7855 - val_acc: 0.6144
#
# Epoch 00053: val_loss did not improve from 4.67934
# Epoch 54/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9480 - acc: 0.8153 - val_loss: 4.7132 - val_acc: 0.6275
#
# Epoch 00054: val_loss did not improve from 4.67934
# Epoch 55/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9448 - acc: 0.8162 - val_loss: 4.7733 - val_acc: 0.6216
#
# Epoch 00055: val_loss did not improve from 4.67934
# Epoch 56/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9415 - acc: 0.8168 - val_loss: 4.7399 - val_acc: 0.6240
#
# Epoch 00056: val_loss did not improve from 4.67934
# Epoch 57/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9417 - acc: 0.8168 - val_loss: 4.7524 - val_acc: 0.6204
#
# Epoch 00057: val_loss did not improve from 4.67934
# Epoch 58/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 2.9401 - acc: 0.8172 - val_loss: 4.6962 - val_acc: 0.6240
#
# Epoch 00058: val_loss did not improve from 4.67934
# Epoch 59/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9395 - acc: 0.8172 - val_loss: 4.7951 - val_acc: 0.6275
#
# Epoch 00059: val_loss did not improve from 4.67934
# Epoch 60/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9383 - acc: 0.8174 - val_loss: 4.6995 - val_acc: 0.6192
#
# Epoch 00060: val_loss did not improve from 4.67934
# Epoch 61/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9394 - acc: 0.8169 - val_loss: 4.7519 - val_acc: 0.6228
#
# Epoch 00061: val_loss did not improve from 4.67934
# Epoch 62/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9378 - acc: 0.8172 - val_loss: 4.7385 - val_acc: 0.6323
#
# Epoch 00062: val_loss did not improve from 4.67934
# Epoch 63/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9373 - acc: 0.8177 - val_loss: 4.7105 - val_acc: 0.6263
#
# Epoch 00063: val_loss did not improve from 4.67934
# Epoch 64/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9367 - acc: 0.8175 - val_loss: 4.7286 - val_acc: 0.6263
#
# Epoch 00064: val_loss did not improve from 4.67934
# Epoch 65/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 2.9362 - acc: 0.8175 - val_loss: 4.7327 - val_acc: 0.6228
#
# Epoch 00065: val_loss did not improve from 4.67934
# Epoch 66/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9353 - acc: 0.8175 - val_loss: 4.7022 - val_acc: 0.6287
#
# Epoch 00066: val_loss did not improve from 4.67934
# Epoch 67/100
# 6680/6680 [==============================] - 1s 133us/step - loss: 2.9378 - acc: 0.8174 - val_loss: 4.7339 - val_acc: 0.6311
#
# Epoch 00067: val_loss did not improve from 4.67934
# Epoch 68/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 2.9368 - acc: 0.8174 - val_loss: 4.6934 - val_acc: 0.6347
#
# Epoch 00068: val_loss did not improve from 4.67934
# Epoch 69/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9376 - acc: 0.8175 - val_loss: 4.6699 - val_acc: 0.6216
#
# Epoch 00069: val_loss improved from 4.67934 to 4.66985, saving model to dogvgg16.weights.best.hdf5
# Epoch 70/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9381 - acc: 0.8175 - val_loss: 4.7149 - val_acc: 0.6299
#
# Epoch 00070: val_loss did not improve from 4.66985
# Epoch 71/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9378 - acc: 0.8174 - val_loss: 4.6877 - val_acc: 0.6299
#
# Epoch 00071: val_loss did not improve from 4.66985
# Epoch 72/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9368 - acc: 0.8174 - val_loss: 4.6981 - val_acc: 0.6323
#
# Epoch 00072: val_loss did not improve from 4.66985
# Epoch 73/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9378 - acc: 0.8174 - val_loss: 4.7350 - val_acc: 0.6323
#
# Epoch 00073: val_loss did not improve from 4.66985
# Epoch 74/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9378 - acc: 0.8174 - val_loss: 4.6983 - val_acc: 0.6323
#
# Epoch 00074: val_loss did not improve from 4.66985
# Epoch 75/100
# 6680/6680 [==============================] - 1s 133us/step - loss: 2.9378 - acc: 0.8174 - val_loss: 4.6578 - val_acc: 0.6407
#
# Epoch 00075: val_loss improved from 4.66985 to 4.65778, saving model to dogvgg16.weights.best.hdf5
# Epoch 76/100
# 6680/6680 [==============================] - 1s 133us/step - loss: 2.9365 - acc: 0.8175 - val_loss: 4.7330 - val_acc: 0.6335
#
# Epoch 00076: val_loss did not improve from 4.65778
# Epoch 77/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9365 - acc: 0.8175 - val_loss: 4.6935 - val_acc: 0.6371
#
# Epoch 00077: val_loss did not improve from 4.65778
# Epoch 78/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9368 - acc: 0.8175 - val_loss: 4.7084 - val_acc: 0.6395
#
# Epoch 00078: val_loss did not improve from 4.65778
# Epoch 79/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9375 - acc: 0.8175 - val_loss: 4.6831 - val_acc: 0.6359
#
# Epoch 00079: val_loss did not improve from 4.65778
# Epoch 80/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9378 - acc: 0.8175 - val_loss: 4.6701 - val_acc: 0.6395
#
# Epoch 00080: val_loss did not improve from 4.65778
# Epoch 81/100
# 6680/6680 [==============================] - 1s 139us/step - loss: 2.9363 - acc: 0.8177 - val_loss: 4.7072 - val_acc: 0.6263
#
# Epoch 00081: val_loss did not improve from 4.65778
# Epoch 82/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9355 - acc: 0.8177 - val_loss: 4.6816 - val_acc: 0.6371
#
# Epoch 00082: val_loss did not improve from 4.65778
# Epoch 83/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9381 - acc: 0.8175 - val_loss: 4.7061 - val_acc: 0.6347
#
# Epoch 00083: val_loss did not improve from 4.65778
# Epoch 84/100
# 6680/6680 [==============================] - 1s 132us/step - loss: 2.9373 - acc: 0.8175 - val_loss: 4.7348 - val_acc: 0.6323
#
# Epoch 00084: val_loss did not improve from 4.65778
# Epoch 85/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9375 - acc: 0.8175 - val_loss: 4.7115 - val_acc: 0.6359
#
# Epoch 00085: val_loss did not improve from 4.65778
# Epoch 86/100
# 6680/6680 [==============================] - 1s 133us/step - loss: 2.9369 - acc: 0.8175 - val_loss: 4.6710 - val_acc: 0.6383
#
# Epoch 00086: val_loss did not improve from 4.65778
# Epoch 87/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9369 - acc: 0.8175 - val_loss: 4.6932 - val_acc: 0.6311
#
# Epoch 00087: val_loss did not improve from 4.65778
# Epoch 88/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9377 - acc: 0.8175 - val_loss: 4.6780 - val_acc: 0.6419
#
# Epoch 00088: val_loss did not improve from 4.65778
# Epoch 89/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9360 - acc: 0.8175 - val_loss: 4.6777 - val_acc: 0.6335
#
# Epoch 00089: val_loss did not improve from 4.65778
# Epoch 90/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9377 - acc: 0.8174 - val_loss: 4.6938 - val_acc: 0.6359
#
# Epoch 00090: val_loss did not improve from 4.65778
# Epoch 91/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 2.9368 - acc: 0.8177 - val_loss: 4.7046 - val_acc: 0.6323
#
# Epoch 00091: val_loss did not improve from 4.65778
# Epoch 92/100
# 6680/6680 [==============================] - 1s 138us/step - loss: 2.9357 - acc: 0.8177 - val_loss: 4.6866 - val_acc: 0.6347
#
# Epoch 00092: val_loss did not improve from 4.65778
# Epoch 93/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9363 - acc: 0.8175 - val_loss: 4.7074 - val_acc: 0.6335
#
# Epoch 00093: val_loss did not improve from 4.65778
# Epoch 94/100
# 6680/6680 [==============================] - 1s 136us/step - loss: 2.9381 - acc: 0.8172 - val_loss: 4.7173 - val_acc: 0.6311
#
# Epoch 00094: val_loss did not improve from 4.65778
# Epoch 95/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9383 - acc: 0.8175 - val_loss: 4.7036 - val_acc: 0.6347
#
# Epoch 00095: val_loss did not improve from 4.65778
# Epoch 96/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9375 - acc: 0.8175 - val_loss: 4.7118 - val_acc: 0.6359
#
# Epoch 00096: val_loss did not improve from 4.65778
# Epoch 97/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9378 - acc: 0.8174 - val_loss: 4.7031 - val_acc: 0.6347
#
# Epoch 00097: val_loss did not improve from 4.65778
# Epoch 98/100
# 6680/6680 [==============================] - 1s 135us/step - loss: 2.9366 - acc: 0.8175 - val_loss: 4.7219 - val_acc: 0.6311
#
# Epoch 00098: val_loss did not improve from 4.65778
# Epoch 99/100
# 6680/6680 [==============================] - 1s 132us/step - loss: 2.9324 - acc: 0.8174 - val_loss: 4.7437 - val_acc: 0.6251
#
# Epoch 00099: val_loss did not improve from 4.65778
# Epoch 100/100
# 6680/6680 [==============================] - 1s 134us/step - loss: 2.9102 - acc: 0.8160 - val_loss: 4.8024 - val_acc: 0.6168
#
# Epoch 00100: val_loss did not improve from 4.65778

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy (Model 2)

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('dogvgg16.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set (Model 2)

# %%
# get index of predicted dog breed for each image in test set
vgg16_predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) 
                     for feature in test_vgg16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(vgg16_predictions)==
                           np.argmax(test_targets, axis=1))/len(vgg16_predictions)
print('\nTest accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 64.3541%
