# %% [markdown]
# <a href="https://colab.research.google.com/github/joaopamaral/aind2-cnn/blob/master/cifar10-classification/cifar10_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0820 23:17:08.104060 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0820 23:17:08.120740 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0820 23:17:08.123304 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0820 23:17:08.150430 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0820 23:17:08.151183 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0820 23:17:08.901880 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0820 23:17:08.971400 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0820 23:17:08.982200 139734277552000 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 500)               2000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 1,073,974
# Trainable params: 1,072,526
# Non-trainable params: 1,448
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
# Out:
# W0820 23:17:09.326201 139734277552000 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=256, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=1, shuffle=True)
# Out:
# W0820 23:17:09.479678 139734277552000 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 7s 152us/step - loss: 1.7806 - acc: 0.4185 - val_loss: 1.5177 - val_acc: 0.4688
#
# Epoch 00001: val_loss improved from inf to 1.51774, saving model to model.weights.best.hdf5
# Epoch 2/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 1.2990 - acc: 0.5428 - val_loss: 1.2579 - val_acc: 0.5658
#
# Epoch 00002: val_loss improved from 1.51774 to 1.25786, saving model to model.weights.best.hdf5
# Epoch 3/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 1.1289 - acc: 0.5962 - val_loss: 2.1641 - val_acc: 0.4062
#
# Epoch 00003: val_loss did not improve from 1.25786
# Epoch 4/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 1.0227 - acc: 0.6383 - val_loss: 1.0480 - val_acc: 0.6310
#
# Epoch 00004: val_loss improved from 1.25786 to 1.04799, saving model to model.weights.best.hdf5
# Epoch 5/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.9527 - acc: 0.6637 - val_loss: 1.0738 - val_acc: 0.6420
#
# Epoch 00005: val_loss did not improve from 1.04799
# Epoch 6/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.8925 - acc: 0.6822 - val_loss: 0.9131 - val_acc: 0.6850
#
# Epoch 00006: val_loss improved from 1.04799 to 0.91311, saving model to model.weights.best.hdf5
# Epoch 7/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.8435 - acc: 0.7011 - val_loss: 1.1906 - val_acc: 0.6292
#
# Epoch 00007: val_loss did not improve from 0.91311
# Epoch 8/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.8068 - acc: 0.7142 - val_loss: 0.7834 - val_acc: 0.7266
#
# Epoch 00008: val_loss improved from 0.91311 to 0.78343, saving model to model.weights.best.hdf5
# Epoch 9/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.7663 - acc: 0.7288 - val_loss: 0.7954 - val_acc: 0.7248
#
# Epoch 00009: val_loss did not improve from 0.78343
# Epoch 10/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.7422 - acc: 0.7372 - val_loss: 0.7267 - val_acc: 0.7488
#
# Epoch 00010: val_loss improved from 0.78343 to 0.72670, saving model to model.weights.best.hdf5
# Epoch 11/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.7108 - acc: 0.7502 - val_loss: 0.6865 - val_acc: 0.7684
#
# Epoch 00011: val_loss improved from 0.72670 to 0.68654, saving model to model.weights.best.hdf5
# Epoch 12/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.6879 - acc: 0.7561 - val_loss: 0.9110 - val_acc: 0.7036
#
# Epoch 00012: val_loss did not improve from 0.68654
# Epoch 13/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.6674 - acc: 0.7642 - val_loss: 0.8510 - val_acc: 0.7316
#
# Epoch 00013: val_loss did not improve from 0.68654
# Epoch 14/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.6510 - acc: 0.7679 - val_loss: 0.6786 - val_acc: 0.7764
#
# Epoch 00014: val_loss improved from 0.68654 to 0.67859, saving model to model.weights.best.hdf5
# Epoch 15/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.6265 - acc: 0.7765 - val_loss: 0.6694 - val_acc: 0.7764
#
# Epoch 00015: val_loss improved from 0.67859 to 0.66939, saving model to model.weights.best.hdf5
# Epoch 16/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.6077 - acc: 0.7848 - val_loss: 0.7393 - val_acc: 0.7618
#
# Epoch 00016: val_loss did not improve from 0.66939
# Epoch 17/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.5931 - acc: 0.7901 - val_loss: 0.9093 - val_acc: 0.7266
#
# Epoch 00017: val_loss did not improve from 0.66939
# Epoch 18/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.5863 - acc: 0.7923 - val_loss: 0.7809 - val_acc: 0.7492
#
# Epoch 00018: val_loss did not improve from 0.66939
# Epoch 19/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.5679 - acc: 0.7984 - val_loss: 0.8279 - val_acc: 0.7414
#
# Epoch 00019: val_loss did not improve from 0.66939
# Epoch 20/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.5527 - acc: 0.8054 - val_loss: 0.9584 - val_acc: 0.7114
#
# Epoch 00020: val_loss did not improve from 0.66939
# Epoch 21/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.5434 - acc: 0.8071 - val_loss: 1.1642 - val_acc: 0.6828
#
# Epoch 00021: val_loss did not improve from 0.66939
# Epoch 22/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.5281 - acc: 0.8119 - val_loss: 0.6525 - val_acc: 0.7846
#
# Epoch 00022: val_loss improved from 0.66939 to 0.65245, saving model to model.weights.best.hdf5
# Epoch 23/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.5161 - acc: 0.8159 - val_loss: 0.7195 - val_acc: 0.7746
#
# Epoch 00023: val_loss did not improve from 0.65245
# Epoch 24/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.5122 - acc: 0.8198 - val_loss: 0.7227 - val_acc: 0.7668
#
# Epoch 00024: val_loss did not improve from 0.65245
# Epoch 25/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.4968 - acc: 0.8252 - val_loss: 0.7614 - val_acc: 0.7672
#
# Epoch 00025: val_loss did not improve from 0.65245
# Epoch 26/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4926 - acc: 0.8245 - val_loss: 0.7737 - val_acc: 0.7628
#
# Epoch 00026: val_loss did not improve from 0.65245
# Epoch 27/50
# 45000/45000 [==============================] - 4s 84us/step - loss: 0.4777 - acc: 0.8307 - val_loss: 0.7144 - val_acc: 0.7754
#
# Epoch 00027: val_loss did not improve from 0.65245
# Epoch 28/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4727 - acc: 0.8344 - val_loss: 0.8988 - val_acc: 0.7290
#
# Epoch 00028: val_loss did not improve from 0.65245
# Epoch 29/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4633 - acc: 0.8362 - val_loss: 0.8289 - val_acc: 0.7598
#
# Epoch 00029: val_loss did not improve from 0.65245
# Epoch 30/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4633 - acc: 0.8356 - val_loss: 0.7392 - val_acc: 0.7822
#
# Epoch 00030: val_loss did not improve from 0.65245
# Epoch 31/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4488 - acc: 0.8402 - val_loss: 0.8414 - val_acc: 0.7556
#
# Epoch 00031: val_loss did not improve from 0.65245
# Epoch 32/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.4429 - acc: 0.8447 - val_loss: 0.7016 - val_acc: 0.7902
#
# Epoch 00032: val_loss did not improve from 0.65245
# Epoch 33/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4369 - acc: 0.8459 - val_loss: 0.6685 - val_acc: 0.7960
#
# Epoch 00033: val_loss did not improve from 0.65245
# Epoch 34/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4292 - acc: 0.8485 - val_loss: 1.1019 - val_acc: 0.7360
#
# Epoch 00034: val_loss did not improve from 0.65245
# Epoch 35/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4275 - acc: 0.8479 - val_loss: 0.6984 - val_acc: 0.7982
#
# Epoch 00035: val_loss did not improve from 0.65245
# Epoch 36/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.4214 - acc: 0.8502 - val_loss: 0.7623 - val_acc: 0.7880
#
# Epoch 00036: val_loss did not improve from 0.65245
# Epoch 37/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.4150 - acc: 0.8537 - val_loss: 0.6353 - val_acc: 0.7936
#
# Epoch 00037: val_loss improved from 0.65245 to 0.63528, saving model to model.weights.best.hdf5
# Epoch 38/50
# 45000/45000 [==============================] - 4s 86us/step - loss: 0.4144 - acc: 0.8538 - val_loss: 0.7403 - val_acc: 0.7904
#
# Epoch 00038: val_loss did not improve from 0.63528
# Epoch 39/50
# 45000/45000 [==============================] - 4s 87us/step - loss: 0.4015 - acc: 0.8573 - val_loss: 0.7380 - val_acc: 0.7880
#
# Epoch 00039: val_loss did not improve from 0.63528
# Epoch 40/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3955 - acc: 0.8602 - val_loss: 0.8661 - val_acc: 0.7702
#
# Epoch 00040: val_loss did not improve from 0.63528
# Epoch 41/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3915 - acc: 0.8622 - val_loss: 0.7529 - val_acc: 0.7852
#
# Epoch 00041: val_loss did not improve from 0.63528
# Epoch 42/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3926 - acc: 0.8617 - val_loss: 0.6957 - val_acc: 0.7962
#
# Epoch 00042: val_loss did not improve from 0.63528
# Epoch 43/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3847 - acc: 0.8657 - val_loss: 0.7379 - val_acc: 0.7906
#
# Epoch 00043: val_loss did not improve from 0.63528
# Epoch 44/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3847 - acc: 0.8637 - val_loss: 0.7796 - val_acc: 0.7822
#
# Epoch 00044: val_loss did not improve from 0.63528
# Epoch 45/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3834 - acc: 0.8648 - val_loss: 0.6800 - val_acc: 0.7976
#
# Epoch 00045: val_loss did not improve from 0.63528
# Epoch 46/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3791 - acc: 0.8677 - val_loss: 0.7100 - val_acc: 0.7940
#
# Epoch 00046: val_loss did not improve from 0.63528
# Epoch 47/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3736 - acc: 0.8673 - val_loss: 0.8653 - val_acc: 0.7614
#
# Epoch 00047: val_loss did not improve from 0.63528
# Epoch 48/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3703 - acc: 0.8678 - val_loss: 0.7474 - val_acc: 0.7644
#
# Epoch 00048: val_loss did not improve from 0.63528
# Epoch 49/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3675 - acc: 0.8699 - val_loss: 0.7526 - val_acc: 0.7834
#
# Epoch 00049: val_loss did not improve from 0.63528
# Epoch 50/50
# 45000/45000 [==============================] - 4s 85us/step - loss: 0.3600 - acc: 0.8736 - val_loss: 0.8364 - val_acc: 0.7780
#
# Epoch 00050: val_loss did not improve from 0.63528

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7811

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
